# %%
import sys
sys.path.append("../utils")
import pdtb_utils
import pandas as pd
import json
from os.path import join

base_dir = '../resources/conll16st-en-zh-dev-train-test_LDC2016E50/'

test_types = {'test': 'conll16st-en-03-29-16-test',
              'train': 'conll16st-en-03-29-16-train',
              'blind_test': 'conll15st-en-03-29-16-blind-test',
              'dev': 'conll16st-en-03-29-16-dev'}

def get_relations(test_type, separate_dual_classes=False):
    with open(join(base_dir, test_types[test_type], 'relations.json')) as f:
        for line in f:
            rel = pdtb_utils.DiscourseRelation(json.loads(line.strip()))
            if separate_dual_classes:
                senses = rel.senses().copy()
                for sense in senses:
                    rel.set_senses([sense])
                    if len(rel.senses()) > 1:
                        yield rel
            else:
                yield rel

relations = get_relations('train', separate_dual_classes=False)

df = pd.DataFrame([{'id': rel.relation_id(), 
                    'senses': tuple(rel.senses()), 
                    'relation_type': rel.relation_type(), 
                    'connective_token': rel.connective_token()} 
                   for rel in relations]).set_index('id')

# %%
type_distribution = pd.concat([df.groupby('relation_type').size(), pd.Series(df.count()['relation_type'], index=['Total'])])
type_distribution
# Out:
# AltLex        524
# EntRel       4133
# Explicit    14722
# Implicit    13156
# Total       32535
# dtype: int64

# %%
rels_separate_sense = get_relations('train', separate_dual_classes=True)
df = pd.DataFrame([{'id': rel.relation_id(), 
                    'senses': tuple(rel.senses()), 
                    'relation_type': rel.relation_type(), 
                    'connective_token': rel.connective_token()} 
                   for rel in rels_separate_sense]).set_index('id')
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-a0c3cf62c7ce> in <module>()
#       4                     'relation_type': rel.relation_type(),
#       5                     'connective_token': rel.connective_token()}
# ----> 6                    for rel in rels_separate_sense]).set_index('id')
#       7 df
#
# <ipython-input-100-a0c3cf62c7ce> in <listcomp>(.0)
#       1 rels_separate_sense = get_relations('train', separate_dual_classes=True)
# ----> 2 df = pd.DataFrame([{'id': rel.relation_id(),
#       3                     'senses': tuple(rel.senses()),
#       4                     'relation_type': rel.relation_type(),
#       5                     'connective_token': rel.connective_token()}
#
# <ipython-input-99-cd5c5c0d70c8> in get_relations(test_type, separate_dual_classes)
#      21                 for sense in senses:
#      22                     rel.set_senses([sense])
# ---> 23                     if len(rel.senses() > 1):
#      24                         yield rel
#      25             else:
#
# TypeError: unorderable types: list() > int()

# %%
freq = pd.DataFrame(df.groupby('senses').count().sort_values('connective_token', ascending=False)['connective_token'])
freq['ratio'] = freq['connective_token'] / freq['connective_token'].sum()
with open('../paper/tables/sense_frequency.tex', 'w') as w:
    freq.head(20).to_latex(w)

# %% [markdown]
# ## Initial thoughts
#
# - Temporal contains typical temporal words, "years", "25 days later", etc. This should be fairly easy to solve by asking if it contains a certain set of temporal words.
#
# ## Most common discourse connective token

# %%
df.connective_token = df.connective_token.apply(str.lower)
df.senses = df.senses.apply(lambda x: "+".join(x))

# %%
token_rel_freq = df.groupby(['connective_token', 'senses']).count().sort_values('relation_type', ascending=False).rename(columns={'relation_type': 'freq'})
token_tot = df.groupby('connective_token').count()['senses']
token_ratio = token_rel_freq.divide(token_tot, axis=0, level=0).rename(columns={'freq': 'ratio'})
pd.concat([token_rel_freq, token_ratio], axis=1).sort_values('freq', ascending=False)
# Out:
#                                                                                       freq  \
# connective_token                         senses
#                                          EntRel                                       4133
# and                                      Expansion.Conjunction                        3192
# but                                      Comparison.Contrast                          2290
# because                                  Contingency.Cause                            2141
# also                                     Expansion.Conjunction                        1793
# specifically                             Expansion.Restatement                         911
# so                                       Contingency.Cause                             879
# if                                       Contingency.Condition                         874
# for example                              Expansion.Instantiation                       744
# however                                  Comparison.Contrast                           690
# then                                     Temporal.Asynchronous                         554
# but                                      Comparison.Concession                         545
# for instance                             Expansion.Instantiation                       503
# in particular                            Expansion.Restatement                         473
# while                                    Comparison.Contrast                           446
# in fact                                  Expansion.Conjunction                         418
# as                                       Contingency.Cause                             408
# when                                     Temporal.Synchrony                            388
# while                                    Expansion.Conjunction                         352
# after                                    Temporal.Asynchronous                         347
# as                                       Temporal.Synchrony                            314
# in addition                              Expansion.Conjunction                         312
# furthermore                              Expansion.Conjunction                         294
# as a result                              Contingency.Cause                             287
# but                                      Comparison                                    281
# in fact                                  Expansion.Restatement                         270
# since                                    Contingency.Cause                             249
# indeed                                   Expansion.Restatement                         234
# thus                                     Contingency.Cause                             230
# before                                   Temporal.Asynchronous                         230
# ...                                                                                    ...
# the announcement fueled                  Contingency.Cause                               1
# the announcement was made because of     Contingency.Cause                               1
# this helps explain                       Contingency.Cause                               1
# the appointment increased                Contingency.Cause                               1
# the big reason                           Contingency.Cause                               1
# accordingly                              Expansion.Restatement+Contingency.Cause         1
# the consequences are being felt          Contingency.Cause                               1
# unless                                   Contingency.Condition                           1
# the growth leads to the conclusion       Contingency.Cause                               1
# the gain resulted from                   Contingency.Cause                               1
# this may help explain why                Contingency.Cause                               1
# the funds are in addition to             Expansion.Conjunction                           1
# this left                                Contingency.Cause                               1
# this leads to                            Contingency.Cause                               1
# then                                     Temporal.Asynchronous+Expansion.Conjunction     1
# the response rate, more than 63%, allows Contingency.Cause                               1
# to tackle the problem                    Contingency.Cause                               1
# accordingly                              Expansion.Conjunction                           1
# to this end                              Contingency.Cause                               1
# ultimately                               Temporal.Asynchronous+Contingency.Cause         1
# the decline primarily reflected          Contingency.Cause                               1
# ultimately                               Expansion.Restatement+Contingency.Cause         1
#                                          Expansion.Conjunction                           1
#                                          Expansion+Temporal.Asynchronous                 1
# the difference is that                   Comparison.Contrast                             1
# the drop indicates                       Contingency.Cause                               1
# the ensuing scandal has helped renew     Contingency.Cause                               1
# the expansion will expand                Contingency.Cause                               1
# the flextime may cut                     Contingency.Cause                               1
# yet                                      Expansion.Conjunction+Comparison.Concession     1
#
#                                                                                          ratio
# connective_token                         senses
#                                          EntRel                                       1.000000
# and                                      Expansion.Conjunction                        0.931971
# but                                      Comparison.Contrast                          0.702885
# because                                  Contingency.Cause                            0.990745
# also                                     Expansion.Conjunction                        0.997219
# specifically                             Expansion.Restatement                        0.968119
# so                                       Contingency.Cause                            0.985426
# if                                       Contingency.Condition                        0.988688
# for example                              Expansion.Instantiation                      0.917386
# however                                  Comparison.Contrast                          0.727081
# then                                     Temporal.Asynchronous                        0.929530
# but                                      Comparison.Concession                        0.167281
# for instance                             Expansion.Instantiation                      0.961759
# in particular                            Expansion.Restatement                        0.885768
# while                                    Comparison.Contrast                          0.386817
# in fact                                  Expansion.Conjunction                        0.545692
# as                                       Contingency.Cause                            0.459977
# when                                     Temporal.Synchrony                           0.494268
# while                                    Expansion.Conjunction                        0.305291
# after                                    Temporal.Asynchronous                        0.871859
# as                                       Temporal.Synchrony                           0.354002
# in addition                              Expansion.Conjunction                        1.000000
# furthermore                              Expansion.Conjunction                        0.986577
# as a result                              Contingency.Cause                            0.993080
# but                                      Comparison                                   0.086249
# in fact                                  Expansion.Restatement                        0.352480
# since                                    Contingency.Cause                            0.783019
# indeed                                   Expansion.Restatement                        0.548009
# thus                                     Contingency.Cause                            0.991379
# before                                   Temporal.Asynchronous                        1.000000
# ...                                                                                        ...
# the announcement fueled                  Contingency.Cause                            1.000000
# the announcement was made because of     Contingency.Cause                            1.000000
# this helps explain                       Contingency.Cause                            1.000000
# the appointment increased                Contingency.Cause                            1.000000
# the big reason                           Contingency.Cause                            1.000000
# accordingly                              Expansion.Restatement+Contingency.Cause      0.018182
# the consequences are being felt          Contingency.Cause                            1.000000
# unless                                   Contingency.Condition                        0.012346
# the growth leads to the conclusion       Contingency.Cause                            1.000000
# the gain resulted from                   Contingency.Cause                            1.000000
# this may help explain why                Contingency.Cause                            1.000000
# the funds are in addition to             Expansion.Conjunction                        1.000000
# this left                                Contingency.Cause                            1.000000
# this leads to                            Contingency.Cause                            1.000000
# then                                     Temporal.Asynchronous+Expansion.Conjunction  0.001678
# the response rate, more than 63%, allows Contingency.Cause                            1.000000
# to tackle the problem                    Contingency.Cause                            1.000000
# accordingly                              Expansion.Conjunction                        0.018182
# to this end                              Contingency.Cause                            1.000000
# ultimately                               Temporal.Asynchronous+Contingency.Cause      0.031250
# the decline primarily reflected          Contingency.Cause                            1.000000
# ultimately                               Expansion.Restatement+Contingency.Cause      0.031250
#                                          Expansion.Conjunction                        0.031250
#                                          Expansion+Temporal.Asynchronous              0.031250
# the difference is that                   Comparison.Contrast                          1.000000
# the drop indicates                       Contingency.Cause                            1.000000
# the ensuing scandal has helped renew     Contingency.Cause                            1.000000
# the expansion will expand                Contingency.Cause                            1.000000
# the flextime may cut                     Contingency.Cause                            1.000000
# yet                                      Expansion.Conjunction+Comparison.Concession  0.011236
#
# [1070 rows x 2 columns]
